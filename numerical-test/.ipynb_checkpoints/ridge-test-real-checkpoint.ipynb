# %%
# --- import packages ---
import sys 
sys.path.append("..") 
from source import utils,env,main,test
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
# import random
# import math
# import time
import gc

# %%
X = pd.read_csv("./micromass/pure_spectra_matrix.csv", 
                sep=';',           # Semicolon-separated fields
                header=None,       # No header row
                decimal='.')       # Decimal point (not comma)

# Read the metadata file to get the labels
Y = pd.read_csv("./micromass/pure_spectra_metadata.csv", 
                      sep=';')     # Semicolon-separated fields

# Now X contains your feature matrix (571 rows × 1300 columns)
# And metadata contains your labels/metadata

# %%
Y
# Out:
#      Species  Strain
# 0    RTO.TQH       1
# 1    BUT.YZE       2
# 2    BUT.YZE       2
# 3    BUT.YZE       2
# 4    BUT.YZE       2
# ..       ...     ...
# 566  VVJ.KWJ     212
# 567  VVJ.KWJ     212
# 568  VVJ.KWJ     212
# 569  QBG.CRP     213
# 570  QBG.CRP     213
#
# [571 rows x 2 columns]
